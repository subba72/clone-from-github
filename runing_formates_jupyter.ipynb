# %%
import os
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '.vscode',
#  'index.html',
#  'read.txt',
#  'supermarkets.json',
#  'Untitled.ipynb']

# %%
import pandas

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '.vscode',
#  'costumer_price.csv',
#  'index.html',
#  'read.txt',
#  'runing_formates_jupyter.ipynb',
#  'supermarkets.json']

# %%
df1=pandas.read_csv("costumer_price.csv")
df1
# Out:
#     Series reference   Period  Initially published  Revised
# 0      CPIQ.SE907303  2017.03          1170.192308     1172
# 1      CPIQ.SE907303  2017.06          1000.000000     1000
# 2      CPIQ.SE907303  2017.09          1040.384615     1021
# 3      CPIQ.SE907303  2017.12          1105.000000     1111
# 4      CPIQ.SE907303  2018.03          1124.000000     1117
# ..               ...      ...                  ...      ...
# 149       CPIQ.SE707  2018.09          1031.000000     1030
# 150       CPIQ.SE707  2018.12          1029.000000     1028
# 151       CPIQ.SE707  2019.03           999.000000      997
# 152       CPIQ.SE707  2019.06          1010.000000     1009
# 153       CPIQ.SE707  2019.09          1012.000000     1011
#
# [154 rows x 4 columns]

# %%
df2=pandas.read_json("supermarkets.json")
df2.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df3= pandas.read_csv("http://pythonhow.com/supermarkets.csv")
df3
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2.set_index("Address")
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
a=df2.set_index("Address")
a
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
a.loc["735 Dolores St":"332 Hill St","Country":"ID"]
# Out:
# Empty DataFrame
# Columns: []
# Index: [735 Dolores St, 332 Hill St]

# %%
a.loc["735 Dolores St":"332 Hill St"]
# Out:
#                 ID           City             State Country         Name  \
# Address
# 735 Dolores St   2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      3  San Francisco  California 94114     USA  Super River
#
#                 Employees
# Address
# 735 Dolores St         15
# 332 Hill St            25

# %%
a.loc["735 Dolores St":"332 Hill St","Country"]
# Out:
# Address
# 735 Dolores St    USA
# 332 Hill St       USA
# Name: Country, dtype: object

# %%
a.loc["735 Dolores St":"332 Hill St","Country":"ID"]
# Out:
# Empty DataFrame
# Columns: []
# Index: [735 Dolores St, 332 Hill St]

# %%
a.loc[:,"Employees"]
# Out:
# Address
# 3666 21st St        8
# 735 Dolores St     15
# 332 Hill St        25
# 3995 23rd St       10
# 1056 Sanchez St    12
# 551 Alvarado St    20
# Name: Employees, dtype: int64

# %%
a.loc[:,"Name"]
# Out:
# Address
# 3666 21st St           Madeira
# 735 Dolores St     Bready Shop
# 332 Hill St        Super River
# 3995 23rd St        Ben's Shop
# 1056 Sanchez St        Sanchez
# 551 Alvarado St     Richvalley
# Name: Name, dtype: object

# %%
a.loc[a["Employees"]<15]
# Out:
#                  ID           City       State Country        Name  Employees
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA     Madeira          8
# 3995 23rd St      4  San Francisco    CA 94114     USA  Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA     Sanchez         12

# %%
a.loc['3666 21st St']
# Out:
# ID                       1
# City         San Francisco
# State             CA 94114
# Country                USA
# Name               Madeira
# Employees                8
# Name: 3666 21st St, dtype: object

# %%
a.loc['3666 21st St','Employees']
# Out:
# 8

# %%
a.loc['3666 21st St','Employees':'ID']
# Out:
# Series([], Name: 3666 21st St, dtype: object)

# %%
a
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
a.loc['3666 21st St','City']
# Out:
# 'San Francisco'

# %%
a.loc['3666 21st St','City':'Country']
# Out:
# City       San Francisco
# State           CA 94114
# Country              USA
# Name: 3666 21st St, dtype: object

# %%
a.loc['3666 21st St',:'Country']
# Out:
# ID                     1
# City       San Francisco
# State           CA 94114
# Country              USA
# Name: 3666 21st St, dtype: object

# %%
a.loc['3666 21st St','Country':]
# Out:
# Country          USA
# Name         Madeira
# Employees          8
# Name: 3666 21st St, dtype: object

# %%
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2.loc[:,:]
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2.loc[1:5,'City':'Name']
# Out:
#             City             State Country         Name
# 1  San Francisco          CA 94119     USA  Bready Shop
# 2  San Francisco  California 94114     USA  Super River
# 3  San Francisco          CA 94114     USA   Ben's Shop
# 4  San Francisco        California     USA      Sanchez
# 5  San Francisco          CA 94114     USA   Richvalley

# %%
df2.iloc?

# %%
g= pandas.DataFrame([[1,2],[4,5],[5,8]],index=['cobra','viper','sidewalker'],
                columns=['max_speed','shield'])

# %%
g
# Out:
#             max_speed  shield
# cobra               1       2
# viper               4       5
# sidewalker          5       8

# %%
g.loc[lambda g: g['shield']<8]
# Out:
#        max_speed  shield
# cobra          1       2
# viper          4       5

# %%
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2.iloc[0]
# Out:
# ID                       1
# Address       3666 21st St
# City         San Francisco
# State             CA 94114
# Country                USA
# Name               Madeira
# Employees                8
# Name: 0, dtype: object

# %%
df2.iloc[[0]]
# Out:
#    ID       Address           City     State Country     Name  Employees
# 0   1  3666 21st St  San Francisco  CA 94114     USA  Madeira          8

# %%
type(df2.iloc[0])
# Out:
# pandas.core.series.Series

# %%
type(df2.iloc[[0]])
# Out:
# pandas.core.frame.DataFrame

# %%
df2.iloc[0,1]
# Out:
# '3666 21st St'

# %%
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2.iloc[0,2]
# Out:
# 'San Francisco'

# %%
df2.iloc[0,0]
# Out:
# 1

# %%
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2.iloc[[0,0]]
# Out:
#    ID       Address           City     State Country     Name  Employees
# 0   1  3666 21st St  San Francisco  CA 94114     USA  Madeira          8
# 0   1  3666 21st St  San Francisco  CA 94114     USA  Madeira          8

# %%
df2.iloc[[0,1]]
# Out:
#    ID         Address           City     State Country         Name  Employees
# 0   1    3666 21st St  San Francisco  CA 94114     USA      Madeira          8
# 1   2  735 Dolores St  San Francisco  CA 94119     USA  Bready Shop         15

# %%
df2.iloc[0:3]
# Out:
#    ID         Address           City             State Country         Name  \
# 0   1    3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2  735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3     332 Hill St  San Francisco  California 94114     USA  Super River
#
#    Employees
# 0          8
# 1         15
# 2         25

# %%
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2.ix[3,4]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-3997a7b20148> in <module>
# ----> 1 df2.ix[3,4]
#
# c:\users\mandi\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df2.columns
# Out:
# Index(['ID', 'Address', 'City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2.drop("City",1)
# Out:
#    ID          Address             State Country         Name  Employees
# 0   1     3666 21st St          CA 94114     USA      Madeira          8
# 1   2   735 Dolores St          CA 94119     USA  Bready Shop         15
# 2   3      332 Hill St  California 94114     USA  Super River         25
# 3   4     3995 23rd St          CA 94114     USA   Ben's Shop         10
# 4   5  1056 Sanchez St        California     USA      Sanchez         12
# 5   6  551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
import os

# %%
os.list()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7a38b4f65fa6> in <module>
# ----> 1 os.list()
#
# NameError: name 'os' is not defined

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '.vscode',
#  'costumer_price.csv',
#  'index.html',
#  'read.txt',
#  'runing_formates_jupyter.ipynb',
#  'supermarkets.json']

# %%
import pandas

# %%
df=pandas.read_csv("costumer_price.csv")

# %%
df=pandas.read_json("supermarkets.json")

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
len(df.index)
# Out:
# 6

# %%
df["Continent"]=df.shape[0]*["North America"]

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees      Continent
# 0          8  North America
# 1         15  North America
# 2         25  North America
# 3         10  North America
# 4         12  North America
# 5         20  North America

# %%
df.shape[0]
# Out:
# 6

# %%
df['Continent']= df['Country']+','+ "the earth"

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees      Continent
# 0          8  USA,the earth
# 1         15  USA,the earth
# 2         25  USA,the earth
# 3         10  USA,the earth
# 4         12  USA,the earth
# 5         20  USA,the earth

# %%
dt_t=df.T
dt_t
# Out:
#                        0               1                 2              3  \
# ID                     1               2                 3              4
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# State           CA 94114        CA 94119  California 94114       CA 94114
# Country              USA             USA               USA            USA
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# Employees              8              15                25             10
# Continent  USA,the earth   USA,the earth     USA,the earth  USA,the earth
#
#                          4                5
# ID                       5                6
# Address    1056 Sanchez St  551 Alvarado St
# City         San Francisco    San Francisco
# State           California         CA 94114
# Country                USA              USA
# ...

# %%
dt_t["My Address"]=['100','Dharan','My city','state 1','Nepal','siru','1000','Asia']

# %%
dt_t
# Out:
#                        0               1                 2              3  \
# ID                     1               2                 3              4
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# State           CA 94114        CA 94119  California 94114       CA 94114
# Country              USA             USA               USA            USA
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# Employees              8              15                25             10
# Continent  USA,the earth   USA,the earth     USA,the earth  USA,the earth
#
#                          4                5 My Address
# ID                       5                6        100
# Address    1056 Sanchez St  551 Alvarado St     Dharan
# City         San Francisco    San Francisco    My city
# State           California         CA 94114    state 1
# ...

# %%
df=dt_t.T

# %%
df
# Out:
#              ID          Address           City             State Country  \
# 0             1     3666 21st St  San Francisco          CA 94114     USA
# 1             2   735 Dolores St  San Francisco          CA 94119     USA
# 2             3      332 Hill St  San Francisco  California 94114     USA
# 3             4     3995 23rd St  San Francisco          CA 94114     USA
# 4             5  1056 Sanchez St  San Francisco        California     USA
# 5             6  551 Alvarado St  San Francisco          CA 94114     USA
# My Address  100           Dharan        My city           state 1   Nepal
#
#                    Name Employees      Continent
# 0               Madeira         8  USA,the earth
# 1           Bready Shop        15  USA,the earth
# 2           Super River        25  USA,the earth
# 3            Ben's Shop        10  USA,the earth
# 4               Sanchez        12  USA,the earth
# 5            Richvalley        20  USA,the earth
# ...

# %%
import geodfpy

# %% [raw]
# dir(geopy)

# %%
df
# Out:
#              ID          Address           City             State Country  \
# 0             1     3666 21st St  San Francisco          CA 94114     USA
# 1             2   735 Dolores St  San Francisco          CA 94119     USA
# 2             3      332 Hill St  San Francisco  California 94114     USA
# 3             4     3995 23rd St  San Francisco          CA 94114     USA
# 4             5  1056 Sanchez St  San Francisco        California     USA
# 5             6  551 Alvarado St  San Francisco          CA 94114     USA
# My Address  100           Dharan        My city           state 1   Nepal
#
#                    Name Employees      Continent
# 0               Madeira         8  USA,the earth
# 1           Bready Shop        15  USA,the earth
# 2           Super River        25  USA,the earth
# 3            Ben's Shop        10  USA,the earth
# 4               Sanchez        12  USA,the earth
# 5            Richvalley        20  USA,the earth
# ...

# %%
geopy
# Out:
# <module 'geopy' from 'c:\\users\\mandi\\appdata\\local\\programs\\python\\python38-32\\lib\\site-packages\\geopy\\__init__.py'>

# %%
dir(geopy)
# Out:
# ['ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy.geocoders import Nominatim

# %%
nom= Nominatim()
# Out:
# <ipython-input-44-578bcd50d366>:1: DeprecationWarning: Using Nominatim with the default "geopy/1.21.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   nom= Nominatim()

# %%
n=nom.geocode("3995 23rd St, San Francisco, CA 94114")
n
# Out:
# Location(3995, 23rd Street, Noe Valley, San Francisco, San Francisco City and County, California, 94114, United States of America, (37.7529648, -122.4317141, 0.0))

# %%
type(n)
# Out:
# geopy.location.Location

# %%
n.longitude
# Out:
# -122.4317141

# %%
n.latitude
# Out:
# 37.7529648

# %%
df
# Out:
#              ID          Address           City             State Country  \
# 0             1     3666 21st St  San Francisco          CA 94114     USA
# 1             2   735 Dolores St  San Francisco          CA 94119     USA
# 2             3      332 Hill St  San Francisco  California 94114     USA
# 3             4     3995 23rd St  San Francisco          CA 94114     USA
# 4             5  1056 Sanchez St  San Francisco        California     USA
# 5             6  551 Alvarado St  San Francisco          CA 94114     USA
# My Address  100           Dharan        My city           state 1   Nepal
#
#                    Name Employees      Continent
# 0               Madeira         8  USA,the earth
# 1           Bready Shop        15  USA,the earth
# 2           Super River        25  USA,the earth
# 3            Ben's Shop        10  USA,the earth
# 4               Sanchez        12  USA,the earth
# 5            Richvalley        20  USA,the earth
# ...

# %%
df["Address"]=df['Address']+", "+df["City"]+", "+df["State"]+", "+df["Country"]
df
# Out:
#              ID                                            Address  \
# 0             1         3666 21st St, San Francisco, CA 94114, USA
# 1             2       735 Dolores St, San Francisco, CA 94119, USA
# 2             3  332 Hill St, San Francisco, California 94114, USA
# 3             4         3995 23rd St, San Francisco, CA 94114, USA
# 4             5    1056 Sanchez St, San Francisco, California, USA
# 5             6      551 Alvarado St, San Francisco, CA 94114, USA
# My Address  100                    Dharan, My city, state 1, Nepal
#
#                      City             State Country         Name Employees  \
# 0           San Francisco          CA 94114     USA      Madeira         8
# 1           San Francisco          CA 94119     USA  Bready Shop        15
# 2           San Francisco  California 94114     USA  Super River        25
# 3           San Francisco          CA 94114     USA   Ben's Shop        10
# ...

# %%
df["Coordinates"]= df["Address"].apply(nom.geocode)
df
# Out:
#              ID                                            Address  \
# 0             1         3666 21st St, San Francisco, CA 94114, USA
# 1             2       735 Dolores St, San Francisco, CA 94119, USA
# 2             3  332 Hill St, San Francisco, California 94114, USA
# 3             4         3995 23rd St, San Francisco, CA 94114, USA
# 4             5    1056 Sanchez St, San Francisco, California, USA
# 5             6      551 Alvarado St, San Francisco, CA 94114, USA
# My Address  100                    Dharan, My city, state 1, Nepal
#
#                      City             State Country         Name Employees  \
# 0           San Francisco          CA 94114     USA      Madeira         8
# 1           San Francisco          CA 94119     USA  Bready Shop        15
# 2           San Francisco  California 94114     USA  Super River        25
# 3           San Francisco          CA 94114     USA   Ben's Shop        10
# ...

# %%
df.Coordinates[0]
# Out:
# Location(3666, 21st Street, Noe Valley, San Francisco, San Francisco City and County, California, 94114, United States of America, (37.75648887755102, -122.42934334693878, 0.0))

# %%
df["latitude"]=df['Coordinates'].apply(lambda x:x.latitude if x !=None else None)
df["longitude"]=df['Coordinates'].apply(lambda x:x.longitude if x !=None else None)
df
# Out:
#              ID                                            Address  \
# 0             1         3666 21st St, San Francisco, CA 94114, USA
# 1             2       735 Dolores St, San Francisco, CA 94119, USA
# 2             3  332 Hill St, San Francisco, California 94114, USA
# 3             4         3995 23rd St, San Francisco, CA 94114, USA
# 4             5    1056 Sanchez St, San Francisco, California, USA
# 5             6      551 Alvarado St, San Francisco, CA 94114, USA
# My Address  100                    Dharan, My city, state 1, Nepal
#
#                      City             State Country         Name Employees  \
# 0           San Francisco          CA 94114     USA      Madeira         8
# 1           San Francisco          CA 94119     USA  Bready Shop        15
# 2           San Francisco  California 94114     USA  Super River        25
# 3           San Francisco          CA 94114     USA   Ben's Shop        10
# ...

# %%
d=df.T
d
# Out:
#                                                              0  \
# ID                                                           1
# Address             3666 21st St, San Francisco, CA 94114, USA
# City                                             San Francisco
# State                                                 CA 94114
# Country                                                    USA
# Name                                                   Madeira
# Employees                                                    8
# Continent                                        USA,the earth
# Coordinates  (3666, 21st Street, Noe Valley, San Francisco,...
# latitude                                               37.7565
# longitude                                             -122.429
#
#                                                              1  \
# ID                                                           2
# Address           735 Dolores St, San Francisco, CA 94119, USA
# ...

# %%
df
# Out:
#              ID                                            Address  \
# 0             1         3666 21st St, San Francisco, CA 94114, USA
# 1             2       735 Dolores St, San Francisco, CA 94119, USA
# 2             3  332 Hill St, San Francisco, California 94114, USA
# 3             4         3995 23rd St, San Francisco, CA 94114, USA
# 4             5    1056 Sanchez St, San Francisco, California, USA
# 5             6      551 Alvarado St, San Francisco, CA 94114, USA
# My Address  100                    Dharan, My city, state 1, Nepal
#
#                      City             State Country         Name Employees  \
# 0           San Francisco          CA 94114     USA      Madeira         8
# 1           San Francisco          CA 94119     USA  Bready Shop        15
# 2           San Francisco  California 94114     USA  Super River        25
# 3           San Francisco          CA 94114     USA   Ben's Shop        10
# ...
